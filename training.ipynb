# %%
#data_root = '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data'
#create_meta_file('wav_data', data_root, "train.txt", 16000, 1102, spectrograms=True, phonemes=False)

# %%
def create_meta_file(dataset_name, dataset_root_dir, output_metafile_name, audio_sample_rate, num_fft_freqs, spectrograms=True, phonemes=False):
        """Create the meta-file and spectrograms (mel and linear, optionally) or phonemized utterances (optionally).
        
        Format details:
            Every line of the metadata file contains info about one dataset item.
            The line has following format 
                'id|speaker|language|audio_file_path|mel_spectrogram_path|linear_spectrogram_path|text|phonemized_text'
            And the following must hold
                'audio_file_path' can be empty if loading just spectrograms
                'text' should be carefully normalized and should contain interpunction
                'phonemized_text' can be empty if loading just raw text  
        
        Arguments:
            dataset_name (string): Name of the dataset, loaders.py should contain a function for loading with a corresponding name.
            dataset_root_dir (string): Root directory from which is the dataset build and to which are spectrograms and the meta-file saved..
            output_metafile_name (string): Name of the output meta-file.
            audio_sample_rate (int): Sample rate of audios, used if spectrograms is set True.
            num_fft_freqs (int): Number of frequency bands used during spectrogram computation, used if spectrograms is set True.
        Keyword arguments:
            spectrograms (boolean, default True): If true, spetrograms (both mel and linear) are computed and saved.
            phonemes (boolean, default True): If true, phonemized variants of utterances are computed and saved.
        """

        path = '/content/drive/MyDrive/speech_project'
        # save current sample rate and fft freqs hyperparameters, as we may process dataset with different sample rate
        if spectrograms:
            old_sample_rate = hp.sample_rate
            hp.sample_rate = audio_sample_rate
            old_fft_freqs = hp.num_fft
            hp.num_fft = num_fft_freqs

        # load metafiles, an item is a list like: [text, audiopath, speaker_id, language_code]
        items = dataset.loaders.get_loader_by_name(dataset_name)(path)
        # build dictionaries for translation to IPA from source languages, see utils.text for details
        if phonemes:
            text_lang_pairs = [(i[0], hp.languages[0] if i[3] == "" else i[3]) for i in items]
            phoneme_dicts = text.build_phoneme_dicts(text_lang_pairs)

        # prepare directories which will store spectrograms
        if spectrograms:
            spectrogram_dirs = [os.path.join(path, 'spectrograms'), 
                                os.path.join(path, 'linear_spectrograms')]
            for x in spectrogram_dirs:
                if not os.path.exists(x): os.makedirs(x)

        # iterate through items and build the meta-data_root = '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data'file
        metafile_path = os.path.join(path, output_metafile_name)
        #print(metafile_path)
        with open(metafile_path, 'w', encoding='utf-8') as f:
            Logger.progress(0, prefix='Building metafile:')
            for i in range(len(items)):
                raw_text, audio_path, speaker, language = items[i]
                if language == "": language = hp.languages[0]
                phonemized_text = text.to_phoneme(raw_text, False, language, phoneme_dicts[language]) if phonemes else ""     
                spectrogram_paths = "|"
                if spectrograms:
                    spec_name = f'{str(i).zfill(6)}.npy'
                    #print(os.path.join(dataset_root_dir, audio_path))
                    try:                 
                      audio_data = audio.load(os.path.join(dataset_root_dir, audio_path))
                    except:
                      print(audio_path)
                      continue
                    np.save(os.path.join(spectrogram_dirs[0], spec_name), audio.spectrogram(audio_data, True))
                    np.save(os.path.join(spectrogram_dirs[1], spec_name), audio.spectrogram(audio_data, False))
                    spectrogram_paths = os.path.join('spectrograms', spec_name) + '|' + os.path.join('linear_spectrograms', spec_name)
                print(f'{str(i).zfill(6)}|{speaker}|{language}|{audio_path}|{spectrogram_paths}|{raw_text}|{phonemized_text}', file=f)
                Logger.progress((i + 1) / len(items), prefix='Building metafile:')
        
        # restore the original sample rate and fft freq values
        if spectrograms:
            hp.sample_rate = old_sample_rate
            hp.num_fft = old_fft_freqs

# %%
import sys
import os
import IPython
from IPython.display import Audio

# %%
os.chdir(os.path.expanduser("~"))
    
tacotron_dir = "Multilingual_Text_to_Speech"
#if not os.path.exists(tacotron_dir):
#  ! git clone https://github.com/dina-adel/Multilingual_Text_to_Speech

wavernn_dir = "WaveRNN"
if not os.path.exists(wavernn_dir):
  ! git clone https://github.com/Tomiinek/$wavernn_dir

# %%
! mkdir -p checkpoints
os.chdir(os.path.join(os.path.expanduser("~"), "checkpoints"))

tacotron_chpt = "generated_switching.pyt"
if not os.path.exists(os.path.join(os.path.expanduser("~"), "checkpoints", tacotron_chpt)):
  ! curl -O -L "https://github.com/Tomiinek/Multilingual_Text_to_Speech/releases/download/v1.0/$tacotron_chpt" 

wavernn_chpt = "wavernn_weight.pyt"
if not os.path.exists(os.path.join(os.path.expanduser("~"), "checkpoints", wavernn_chpt)):
  ! curl -O -L "https://github.com/Tomiinek/Multilingual_Text_to_Speech/releases/download/v1.0/$wavernn_chpt"     

os.chdir(os.path.expanduser("~"))

# %%
! pip install soundfile
! pip install phonemizer
! pip install epitran
! apt-get install festival espeak-ng mbrola
# Out:
# Requirement already satisfied: soundfile in ./miniconda3/envs/sar/lib/python3.6/site-packages (0.10.2)
# Requirement already satisfied: cffi>=1.0 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from soundfile) (1.14.5)
# Requirement already satisfied: pycparser in ./miniconda3/envs/sar/lib/python3.6/site-packages (from cffi>=1.0->soundfile) (2.20)
# Requirement already satisfied: phonemizer in ./miniconda3/envs/sar/lib/python3.6/site-packages (2.1)
# Requirement already satisfied: attrs>=18.1 in ./.local/lib/python3.6/site-packages (from phonemizer) (19.3.0)
# Requirement already satisfied: joblib in ./.local/lib/python3.6/site-packages (from phonemizer) (0.17.0)
# Requirement already satisfied: segments in ./miniconda3/envs/sar/lib/python3.6/site-packages (from phonemizer) (2.2.0)
# Requirement already satisfied: regex in ./miniconda3/envs/sar/lib/python3.6/site-packages (from segments->phonemizer) (2020.11.13)
# Requirement already satisfied: clldutils>=1.7.3 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from segments->phonemizer) (3.6.0)
# Requirement already satisfied: csvw>=1.5.6 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from segments->phonemizer) (1.10.1)
# Requirement already satisfied: python-dateutil in ./.local/lib/python3.6/site-packages (from clldutils>=1.7.3->segments->phonemizer) (2.8.1)
# Requirement already satisfied: colorlog in ./miniconda3/envs/sar/lib/python3.6/site-packages (from clldutils>=1.7.3->segments->phonemizer) (4.7.2)
# Requirement already satisfied: tabulate>=0.7.7 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from clldutils>=1.7.3->segments->phonemizer) (0.8.9)
# Requirement already satisfied: isodate in ./miniconda3/envs/sar/lib/python3.6/site-packages (from csvw>=1.5.6->segments->phonemizer) (0.6.0)
# Requirement already satisfied: uritemplate>=3.0.0 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from csvw>=1.5.6->segments->phonemizer) (3.0.1)
# Requirement already satisfied: rfc3986 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from csvw>=1.5.6->segments->phonemizer) (1.4.0)
# Requirement already satisfied: six in ./.local/lib/python3.6/site-packages (from isodate->csvw>=1.5.6->segments->phonemizer) (1.15.0)
# Requirement already satisfied: epitran in ./miniconda3/envs/sar/lib/python3.6/site-packages (1.2)
# Requirement already satisfied: marisa-trie in ./miniconda3/envs/sar/lib/python3.6/site-packages (from epitran) (0.7.5)
# Requirement already satisfied: unicodecsv in ./miniconda3/envs/sar/lib/python3.6/site-packages (from epitran) (0.14.1)
# Requirement already satisfied: panphon>=0.15 in ./miniconda3/envs/sar/lib/python3.6/site-packages (from epitran) (0.17)
# Requirement already satisfied: regex in ./miniconda3/envs/sar/lib/python3.6/site-packages (from epitran) (2020.11.13)
# Requirement already satisfied: setuptools in ./.local/lib/python3.6/site-packages (from epitran) (50.3.2)
# Requirement already satisfied: editdistance in ./miniconda3/envs/sar/lib/python3.6/site-packages (from panphon>=0.15->epitran) (0.5.3)
# Requirement already satisfied: munkres in ./miniconda3/envs/sar/lib/python3.6/site-packages (from panphon>=0.15->epitran) (1.1.4)
# Requirement already satisfied: PyYAML in ./miniconda3/envs/sar/lib/python3.6/site-packages (from panphon>=0.15->epitran) (5.4.1)
# Requirement already satisfied: numpy in ./miniconda3/envs/sar/lib/python3.6/site-packages (from panphon>=0.15->epitran) (1.19.2)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
os.chdir(os.path.join(os.path.expanduser("~"), tacotron_dir))
if "utils" in sys.modules: del sys.modules["utils"]
import os
import time
import datetime
import math
import numpy as np
import torch
from torch.utils.data import DataLoader

import dataset.loaders
from dataset.dataset import TextToSpeechDatasetCollection, TextToSpeechCollate, TextToSpeechDataset
from params.params import Params as hp
from utils import audio, text
from modules.tacotron2 import Tacotron, TacotronLoss
from utils.logging import Logger
from utils.samplers import RandomImbalancedSampler, PerfectBatchSampler
from utils import lengths_to_mask, to_gpu

# %%
# !python3 /home/ires/Multilingual_Text_to_Speech/train.py --base_directory /home/ires/Multilingual_Text_to_Speech --hyper_parameters ar --data_root /home/ires/Multilingual_Text_to_Speech/data
# Out:
# item is:  {'id': '000000', 'speaker': '1', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/1/1-1.wav ', 'spectrogram': 'spectrograms/000000.npy', 'linear_spectrogram': 'linear_spectrograms/000000.npy', 'text': 'ارتفعت الأسهم الكويتية ارتفاعا طفيفا اليوم السبت', 'phonemes': ''}
# speakers:  {'1'}
# item is:  {'id': '000003', 'speaker': '2', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/2/2-01.wav ', 'spectrogram': 'spectrograms/000003.npy', 'linear_spectrogram': 'linear_spectrograms/000003.npy', 'text': 'مجال الإصلاحات السياسية', 'phonemes': ''}
# speakers:  {'2', '1'}
# item is:  {'id': '000038', 'speaker': '3', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/3/3-1.wav ', 'spectrogram': 'spectrograms/000038.npy', 'linear_spectrogram': 'linear_spectrograms/000038.npy', 'text': 'توج المنتخب التونسي للمرة السابعة', 'phonemes': ''}
# speakers:  {'3', '2', '1'}
# item is:  {'id': '000046', 'speaker': '4', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/4/4-1.wav ', 'spectrogram': 'spectrograms/000046.npy', 'linear_spectrogram': 'linear_spectrograms/000046.npy', 'text': 'المنتخب المصري المضيف', 'phonemes': ''}
# speakers:  {'4', '3', '2', '1'}
# item is:  {'id': '000052', 'speaker': '5', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/5/5-01.wav ', 'spectrogram': 'spectrograms/000052.npy', 'linear_spectrogram': 'linear_spectrograms/000052.npy', 'text': 'بسعر مئة وخمسة وثمانين ريالا للسهم', 'phonemes': ''}
# speakers:  {'1', '4', '2', '3', '5'}
# item is:  {'id': '000074', 'speaker': '6', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/6/6-01.wav ', 'spectrogram': 'spectrograms/000074.npy', 'linear_spectrogram': 'linear_spectrograms/000074.npy', 'text': 'يجرى وضع اللمسات الأخيرة لتأسيس شركة مساهمة للبتروكيماويات', 'phonemes': ''}
# speakers:  {'6', '1', '4', '2', '3', '5'}
# item is:  {'id': '000097', 'speaker': '7', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/7/7-01.wav ', 'spectrogram': 'spectrograms/000097.npy', 'linear_spectrogram': 'linear_spectrograms/000097.npy', 'text': 'حثت جماعة تجارية أمريكية بارزة أعضاء الكونجرس الأمريكي على مقاومة إغراء فرض عقوبات من جانب واحد على إيران', 'phonemes': ''}
# speakers:  {'6', '1', '4', '2', '3', '5', '7'}
# item is:  {'id': '000123', 'speaker': '8', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/8/8-1.wav ', 'spectrogram': 'spectrograms/000123.npy', 'linear_spectrogram': 'linear_spectrograms/000123.npy', 'text': 'يبدي السعوديون اهتماما واضحا في اكتتاب بنك الريان القطري', 'phonemes': ''}
# speakers:  {'6', '8', '1', '4', '2', '3', '5', '7'}
# item is:  {'id': '000130', 'speaker': '9', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/9/9-1.wav ', 'spectrogram': 'spectrograms/000130.npy', 'linear_spectrogram': 'linear_spectrograms/000130.npy', 'text': 'نائب محافظ البنك المركزي الإيراني إن بلاده', 'phonemes': ''}
# speakers:  {'6', '8', '9', '1', '4', '2', '3', '5', '7'}
# item is:  {'id': '000133', 'speaker': '10', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/10/10-01.wav ', 'spectrogram': 'spectrograms/000133.npy', 'linear_spectrogram': 'linear_spectrograms/000133.npy', 'text': 'قال نائب محافظ البنك المركزي الإيراني إن بلاده', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '4', '2', '3', '5', '7'}
# item is:  {'id': '000143', 'speaker': '11', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/11/11-1.wav ', 'spectrogram': 'spectrograms/000143.npy', 'linear_spectrogram': 'linear_spectrograms/000143.npy', 'text': 'وتكلفته سبعة مليارات دولار مع إيران', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '11', '4', '2', '3', '5', '7'}
# item is:  {'id': '000147', 'speaker': '12', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/12/12-1.wav ', 'spectrogram': 'spectrograms/000147.npy', 'linear_spectrogram': 'linear_spectrograms/000147.npy', 'text': 'نزلت أسهم قوقل عند إغلاق التداولات', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '11', '4', '2', '3', '5', '7'}
# item is:  {'id': '000152', 'speaker': '14', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/14/14-1.wav ', 'spectrogram': 'spectrograms/000152.npy', 'linear_spectrogram': 'linear_spectrograms/000152.npy', 'text': 'إفريقيا أيضا قاد مهاجم برشلونه الكامروني صمويليت منتخب بلاده لفوز مستحق على نظيره الأنقولي بثلاثة أهداف لهدف', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '11', '4', '2', '3', '14', '5', '7'}
# item is:  {'id': '000156', 'speaker': '15', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/15/15-01.wav ', 'spectrogram': 'spectrograms/000156.npy', 'linear_spectrogram': 'linear_spectrograms/000156.npy', 'text': 'حدت شركة السيارات الألمانية فولزفاجن وشركة السيارات الألمانية الأمريكية كرايزلر جهودهما لتصنيع سيارة من نوع ميني فان في الولايات المتحدة', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '11', '4', '2', '3', '14', '15', '5', '7'}
# item is:  {'id': '000187', 'speaker': '16', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/16/16-01.wav ', 'spectrogram': 'spectrograms/000187.npy', 'linear_spectrogram': 'linear_spectrograms/000187.npy', 'text': 'نجح ريال مدريد في تعويض الهدف الذي سكن مرماه ليفوز على فريق قاردز بثلاثة أهداف مقابل هدف واحد', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '11', '4', '2', '3', '14', '15', '16', '5', '7'}
# item is:  {'id': '000198', 'speaker': '17', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/17/17-01.wav ', 'spectrogram': 'spectrograms/000198.npy', 'linear_spectrogram': 'linear_spectrograms/000198.npy', 'text': 'وكانت المباراة سجالا بين الفريقين', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '11', '4', '2', '3', '14', '15', '16', '5', '17', '7'}
# item is:  {'id': '000267', 'speaker': '18', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/18/18-01.wav ', 'spectrogram': 'spectrograms/000267.npy', 'linear_spectrogram': 'linear_spectrograms/000267.npy', 'text': 'أبرمت الصين والسعودية عددا من الاتفاقيات الاقتصادية خلال زيارة العاهل السعودي الملك عبدالله بن عبد العزيز لبكين', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '18', '11', '4', '2', '3', '14', '15', '16', '5', '17', '7'}
# item is:  {'id': '000336', 'speaker': '19', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/19/19-1.wav ', 'spectrogram': 'spectrograms/000336.npy', 'linear_spectrogram': 'linear_spectrograms/000336.npy', 'text': 'استهلت نيجيريا مبارياتها في كأس أمم أفريقيا الجارية في مصر بالفوز على جارتها غانا بهدف وحيد لحساب المجموعة الرابعة', 'phonemes': ''}
# speakers:  {'6', '8', '10', '9', '1', '12', '18', '11', '4', '2', '3', '14', '15', '16', '5', '17', '19', '7'}
# item is:  {'id': '000340', 'speaker': '20', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/20/20-1.wav ', 'spectrogram': 'spectrograms/000340.npy', 'linear_spectrogram': 'linear_spectrograms/000340.npy', 'text': 'هذا وسيكون ملعب القاهرة الدولي مساء الثلاثاء على موعد مع اللقاء المرتقب بين منتخبي مصر', 'phonemes': ''}
# speakers:  {'6', '8', '20', '10', '9', '1', '12', '18', '11', '4', '2', '3', '14', '15', '16', '5', '17', '19', '7'}
# item is:  {'id': '000345', 'speaker': '21', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/21/21-01.wav ', 'spectrogram': 'spectrograms/000345.npy', 'linear_spectrogram': 'linear_spectrograms/000345.npy', 'text': 'ونبقى مع أخبار سوق المال السعودي', 'phonemes': ''}
# speakers:  {'6', '8', '20', '10', '9', '1', '12', '18', '11', '4', '2', '3', '14', '15', '16', '5', '17', '21', '19', '7'}
# item is:  {'id': '000370', 'speaker': '22', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/22/22-01.wav ', 'spectrogram': 'spectrograms/000370.npy', 'linear_spectrogram': 'linear_spectrograms/000370.npy', 'text': 'أهلا بكم من جديد', 'phonemes': ''}
# speakers:  {'6', '1', '12', '15', '17', '21', '2', '16', '18', '11', '5', '8', '10', '9', '7', '22', '4', '14', '19', '3', '20'}
# item is:  {'id': '000449', 'speaker': '32', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/32/32-01.wav ', 'spectrogram': 'spectrograms/000449.npy', 'linear_spectrogram': 'linear_spectrograms/000449.npy', 'text': 'لكنه استبعد التوصل إلى اتفاق مع إسلام أباد في المجال النووي كما فعل مع الهند', 'phonemes': ''}
# speakers:  {'6', '1', '12', '15', '17', '32', '21', '2', '16', '18', '11', '5', '8', '10', '9', '7', '22', '4', '14', '19', '3', '20'}
# item is:  {'id': '000461', 'speaker': '33', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/33/33-01.wav ', 'spectrogram': 'spectrograms/000461.npy', 'linear_spectrogram': 'linear_spectrograms/000461.npy', 'text': 'بفضل ارتفاع أسعار النفط واستقرار أوضاع المنطقة سياسيا وأمنيا', 'phonemes': ''}
# speakers:  {'6', '1', '12', '15', '17', '32', '21', '33', '2', '16', '18', '11', '5', '8', '10', '9', '7', '22', '4', '14', '19', '3', '20'}
# item is:  {'id': '000484', 'speaker': '34', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/34/34-01.wav ', 'spectrogram': 'spectrograms/000484.npy', 'linear_spectrogram': 'linear_spectrograms/000484.npy', 'text': 'وكان رئيس البنك المركزي الأوروبي جان كلود ريشيه قال إن قاعدة النمو تتزايد وتقوى في منطقة اليورو', 'phonemes': ''}
# speakers:  {'6', '1', '12', '15', '17', '32', '21', '33', '2', '16', '18', '11', '5', '8', '34', '10', '9', '7', '22', '4', '14', '19', '3', '20'}
# item is:  {'id': '000502', 'speaker': '35', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/35/35-01.wav ', 'spectrogram': 'spectrograms/000502.npy', 'linear_spectrogram': 'linear_spectrograms/000502.npy', 'text': 'إنشاء مصنع للمادة الأولية للألياف الزجاجية', 'phonemes': ''}
# speakers:  {'6', '1', '12', '15', '17', '32', '21', '33', '2', '35', '16', '18', '11', '5', '8', '34', '10', '9', '7', '22', '4', '14', '19', '3', '20'}
# item is:  {'id': '000537', 'speaker': '36', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/36/36-01.wav ', 'spectrogram': 'spectrograms/000537.npy', 'linear_spectrogram': 'linear_spectrograms/000537.npy', 'text': 'من الناحية العددية', 'phonemes': ''}
# speakers:  {'6', '1', '12', '15', '17', '32', '21', '33', '2', '35', '16', '18', '11', '5', '8', '34', '10', '9', '7', '22', '4', '14', '36', '19', '3', '20'}
# item is:  {'id': '000557', 'speaker': '37', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/37/37-1.wav ', 'spectrogram': 'spectrograms/000557.npy', 'linear_spectrogram': 'linear_spectrograms/000557.npy', 'text': 'انخفض سعر مزيج برنت خام القياس الأوروبي', 'phonemes': ''}
# speakers:  {'6', '1', '12', '37', '15', '17', '32', '21', '33', '2', '35', '16', '18', '11', '5', '8', '34', '10', '9', '7', '22', '4', '14', '36', '19', '3', '20'}
# item is:  {'id': '000561', 'speaker': '38', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/38/38-01.wav ', 'spectrogram': 'spectrograms/000561.npy', 'linear_spectrogram': 'linear_spectrograms/000561.npy', 'text': 'على هامش الزيارة التي يقوم بها خادم الحرمين الشريفين الملك عبد الله بن عبد العزيز لجمهورية الهند رعى خادم الحرمين الشريفين', 'phonemes': ''}
# speakers:  {'6', '1', '12', '37', '15', '17', '32', '21', '38', '33', '2', '35', '16', '18', '11', '5', '8', '34', '10', '9', '7', '22', '4', '14', '36', '19', '3', '20'}
# item is:  {'id': '000586', 'speaker': '39', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data
 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/49/49-01.wav ', 'spectrogram': 'spectrograms/000836.npy', 'linear_spectrogram': 'linear_spectrograms/000836.npy', 'text': 'أهلا بكم من جديد', 'phonemes': ''}
# speakers:  {'6', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '38', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '44', '22', '4', '14', '36', '19', '3', '20'}
# item is:  {'id': '000880', 'speaker': '50', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/50/50-01.wav ', 'spectrogram': 'spectrograms/000880.npy', 'linear_spectrogram': 'linear_spectrograms/000880.npy', 'text': 'ومن ناحية أخرى أقرت المحكمة العليا في لندن صفقة استحواذ شركة دبي للموانئ العالمية على بي أندوا البريطانية', 'phonemes': ''}
# speakers:  {'6', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '38', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '000904', 'speaker': '60', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/60/60-01.wav ', 'spectrogram': 'spectrograms/000904.npy', 'linear_spectrogram': 'linear_spectrograms/000904.npy', 'text': 'والذي أشار إلى زيادة عدد مليارديرات العالم إلى مستوى قياسي في العام الماضي', 'phonemes': ''}
# speakers:  {'6', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '000922', 'speaker': '61', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/61/61-01.wav ', 'spectrogram': 'spectrograms/000922.npy', 'linear_spectrogram': 'linear_spectrograms/000922.npy', 'text': 'أعلنت شركة سابك للصناعات الأساسية أن الشركة ستصدر قريبا صكوكا إسلامية محلية', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '000941', 'speaker': '62', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/62/62-01.wav ', 'spectrogram': 'spectrograms/000941.npy', 'linear_spectrogram': 'linear_spectrograms/000941.npy', 'text': 'تسعى مصر إلى مضاعفة صادراتها من الغاز الطبيعي في غضون الأعوام الخمسة المقبلة وتطوير احتياطاتها', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '000966', 'speaker': '64', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/64/64-02.wav ', 'spectrogram': 'spectrograms/000966.npy', 'linear_spectrogram': 'linear_spectrograms/000966.npy', 'text': 'وأثبت بجدارة أنه قطاع صناعي يواصل توسيع نطاق تطويره من جهة', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '64', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001009', 'speaker': '65', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/65/65-01.wav ', 'spectrogram': 'spectrograms/001009.npy', 'linear_spectrogram': 'linear_spectrograms/001009.npy', 'text': 'وتسعى إلى استقطاب عشرين مليار دولار', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '18', '11', '43', '5', '8', '34', '10', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001030', 'speaker': '66', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/66/66-01.wav ', 'spectrogram': 'spectrograms/001030.npy', 'linear_spectrogram': 'linear_spectrograms/001030.npy', 'text': 'وأعلنت شركة طيران الجزيرة عن تعزيز شبكة محطتها الإقليمية لتشمل مدينة حلب السورية', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '66', '18', '11', '43', '5', '8', '34', '10', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001056', 'speaker': '67', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/67/67-1.wav ', 'spectrogram': 'spectrograms/001056.npy', 'linear_spectrogram': 'linear_spectrograms/001056.npy', 'text': 'والشركة التي تأسست في عام اثنين وثلاثين', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '60', '40', '47', '33', '2', '35', '41', '39', '16', '67', '66', '18', '11', '43', '5', '8', '34', '10', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001063', 'speaker': '68', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/68/68-01.wav ', 'spectrogram': 'spectrograms/001063.npy', 'linear_spectrogram': 'linear_spectrograms/001063.npy', 'text': 'وقدم الطرفان', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '67', '66', '18', '11', '43', '5', '8', '34', '10', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001074', 'speaker': '69', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/69/69-01.wav ', 'spectrogram': 'spectrograms/001074.npy', 'linear_spectrogram': 'linear_spectrograms/001074.npy', 'text': 'على مستوى منطقة الخليج ونقطة الدخول إلى الأسواق العالمية', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '69', '67', '66', '18', '11', '43', '5', '8', '34', '10', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001095', 'speaker': '70', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/70/70-01.wav ', 'spectrogram': 'spectrograms/001095.npy', 'linear_spectrogram': 'linear_spectrograms/001095.npy', 'text': 'صرح كلود مانديل المدير التنفيذي لوكالة الطاقة الدولية', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '69', '67', '66', '18', '11', '43', '5', '8', '34', '10', '70', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001128', 'speaker': '71', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/71/71-01.wav ', 'spectrogram': 'spectrograms/001128.npy', 'linear_spectrogram': 'linear_spectrograms/001128.npy', 'text': 'وقعت شركة الخليج للطاقة مذكرة تفاهم مع هيئة مركز قطر المالي وهيئة التنظيم بمركر قطر المالي', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '10', '70', '9', '7', '64', '65', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001139', 'speaker': '72', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/72/72-01.wav ', 'spectrogram': 'spectrograms/001139.npy', 'linear_spectrogram': 'linear_spectrograms/001139.npy', 'text': 'تتوقع شركة بي إم دبليو تحقيق أرباح قياسية هذا العام', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '10', '70', '9', '7', '64', '65', '72', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001175', 'speaker': '73', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/73/73-01.wav ', 'spectrogram': 'spectrograms/001175.npy', 'linear_spectrogram': 'linear_spectrograms/001175.npy', 'text': 'هاجم وزير الاستثمار المصري محمود محي الدين منتقديه بسبب خطة الحكومة لبيع شركة عمر أفندي لمستثمر سعودي', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '10', '70', '9', '7', '64', '65', '72', '44', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001185', 'speaker': '74', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/74/74-01.wav ', 'spectrogram': 'spectrograms/001185.npy', 'linear_spectrogram': 'linear_spectrograms/001185.npy', 'text': 'اكتشف في مزرعتين للدجاج في غزة الأسبوع الماضي', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001207', 'speaker': '75', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/75/75-01.wav ', 'spectrogram': 'spectrograms/001207.npy', 'linear_spectrogram': 'linear_spectrograms/001207.npy', 'text': 'ثمانين مليار دولار في بلدان الخليج العربية', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '20'}
# item is:  {'id': '001230', 'speaker': '76', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/76/76-01.wav ', 'spectrogram': 'spectrograms/001230.npy', 'linear_spectrogram': 'linear_spectrograms/001230.npy', 'text': 'تحقيق أرباح قياسية هذا العام', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20'}
# item is:  {'id': '001237', 'speaker': '77', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/77/77-01.wav ', 'spectrogram': 'spectrograms/001237.npy', 'linear_spectrogram': 'linear_spectrograms/001237.npy', 'text': 'بخمسة في المئة العام الماضي', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20'}
# item is:  {'id': '001262', 'speaker': '78', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/78/78-01.wav ', 'spectrogram': 'spectrograms/001262.npy', 'linear_spectrogram': 'linear_spectrograms/001262.npy', 'text': 'دخلت شركة تكامل للاستثمار العقاري والسياحي السعودية كشركة مساهمة مغلقة', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '66', '18', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20'}
# item is:  {'id': '001284', 'speaker': '79', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/79/79-01.wav ', 'spectrogram': 'spectrograms/001284.npy', 'linear_spectrogram': 'linear_spectrograms/001284.npy', 'text': 'التابع لشركة طيران الخليج بتكلفة تناهز ثلاثة ملايين وخمس مئة ألف دينار بحريني', 'phonemes': ''}
# speakers:  {'6', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '79', '66', '18', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20'}
# item is:  {'id': '001305', 'speaker': '80', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/80/80-01.wav ', 'spectrogram': 'spectrograms/001305.npy', 'linear_spectrogram': 'linear_spectrograms/001305.npy', 'text': 'حيث يشمل النظام الجديد تعيين مراقب داخلي مستقل بصلاحيات واسعة', 'phonemes': ''}
# speakers:  {'6', '80', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '79', '66', '18', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20'}
# item is:  {'id': '001316', 'speaker': '81', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/81/81-01.wav ', 'spectrogram': 'spectrograms/001316.npy', 'linear_spectrogram': 'linear_spectrograms/001316.npy', 'text': 'ولشبكات النقل', 'phonemes': ''}
# speakers:  {'6', '80', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '79', '66', '18', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001333', 'speaker': '82', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/82/82-01.wav ', 'spectrogram': 'spectrograms/001333.npy', 'linear_spectrogram': 'linear_spectrograms/001333.npy', 'text': 'ولم تستأنف العمل كما كان مزمعا بعد إجراء عمليات الصيانة', 'phonemes': ''}
# speakers:  {'6', '80', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '79', '66', '18', '82', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001351', 'speaker': '83', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/83/83-1.wav ', 'spectrogram': 'spectrograms/001351.npy', 'linear_spectrogram': 'linear_spectrograms/001351.npy', 'text': 'في المغرب تم إنشاء صندوق للاستثمار برأس مال مئتين وثلاثين مليون يورو لتسريع وتيرة بناء فنادق جديدة في البلاد', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '69', '67', '79', '66', '18', '82', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001356', 'speaker': '84', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/84/84-01.wav ', 'spectrogram': 'spectrograms/001356.npy', 'linear_spectrogram': 'linear_spectrograms/001356.npy', 'text': 'وافق مجلس الوزراء الكويتي من حيث المبدأ على إقامة شركة اتصالات تالتة في البلاد', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '84', '69', '67', '79', '66', '18', '82', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001413', 'speaker': '85', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/85/85-01.wav ', 'spectrogram': 'spectrograms/001413.npy', 'linear_spectrogram': 'linear_spectrograms/001413.npy', 'text': 'مذكرة تفاهم لإنشاء مجلس الأعمال السعودي السويسري', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '85', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '84', '69', '67', '79', '66', '18', '82', '11', '43', '5', '78', '8', '34', '75', '10', '70', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001428', 'speaker': '86', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/86/86-01.wav ', 'spectrogram': 'spectrograms/001428.npy', 'linear_spectrogram': 'linear_spectrograms/001428.npy', 'text': 'هي أداة مالية لتنفيذ عمليات السياسات النقدية الرامية إلى امتصاص فائض السيولة النقدية', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '85', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '84', '69', '67', '79', '66', '18', '82', '11', '43', '5', '78', '8', '34', '75', '10', '70', '86', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001461', 'speaker': '88', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/88/88-01.wav ', 'spectrogram': 'spectrograms/001461.npy', 'linear_spectrogram': 'linear_spectrograms/001461.npy', 'text': 'ركزت أعمال المؤتمر الثامن عشر للحاسبات الذي عقد في الرياض على اقتصادات تقنية المعلومات وتوطين التقنية', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '85', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '84', '69', '67', '79', '66', '18', '82', '11', '43', '88', '5', '78', '8', '34', '75', '10', '70', '86', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '20', '81'}
# item is:  {'id': '001489', 'speaker': '89', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/89/89-01.wav ', 'spectrogram': 'spectrograms/001489.npy', 'linear_spectrogram': 'linear_spectrograms/001489.npy', 'text': 'خفضت قطر سعر البيع الرسمي لخامها البري في عقود مارس آذار بأثر رجعي بواقع واحد وعشرين سنتا للبرميل', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '85', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '84', '69', '67', '79', '66', '18', '82', '11', '43', '88', '5', '78', '8', '34', '75', '10', '70', '86', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '89', '20', '81'}
# item is:  {'id': '001507', 'speaker': '90', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data/90/90-01.wav ', 'spectrogram': 'spectrograms/001507.npy', 'linear_spectrogram': 'linear_spectrograms/001507.npy', 'text': 'قد أعرب الديمقراطيون عن قلقهم لعدة مسائل منها عدم وجود اتحادات عمالية', 'phonemes': ''}
# speakers:  {'6', '80', '83', '61', '48', '49', '46', '1', '12', '45', '37', '42', '15', '17', '85', '32', '21', '73', '62', '38', '68', '60', '40', '47', '77', '33', '2', '35', '41', '39', '16', '71', '84', '69', '67', '79', '66', '18', '82', '11', '43', '88', '5', '78', '90', '8', '34', '75', '10', '70', '86', '9', '7', '64', '65', '72', '44', '74', '22', '4', '14', '36', '50', '19', '3', '76', '89', '20', '81'}
# item is:  {'id': '001534', 'speaker': '91', 'language': 'ar', 'audio': '/content/drive/MyDrive/speech_project/Multilingual_Text_to_Speech/data/wav_data
# speakers:  {'80', '275', '953', '928', '49', '141', '962', '12', '45', '37', '42', '955', '124', '236', '303', '253', '111', '277', '112', '94', '130', '248', '300', '907', '151', '223', '931', '930', '93', '99', '217', '269', '84', '97', '251', '925', '254', '263', '929', '66', '18', '82', '149', '228', '237', '250', '290', '208', '258', '211', '103', '904', '160', '138', '239', '34', '108', '125', '153', '218', '291', '939', '913', '134', '22', '36', '129', '156', '225', '268', '3', '270', '122', '224', '947', '142', '1', '234', '85', '204', '900', '114', '133', '943', '963', '73', '126', '212', '261', '136', '210', '952', '264', '272', '157', '123', '203', '47', '105', '221', '222', '298', '121', '118', '41', '39', '107', '255', '257', '265', '922', '958', '233', '295', '100', '219', '924', '940', '67', '79', '213', '938', '11', '113', '98', '116', '932', '8', '252', '256', '906', '934', '75', '161', '88', '86', '216', '226', '301', '950', '72', '44', '271', '4', '278', '119', '146', '220', '48', '273', '76', '89', '7', '260', '941', '276', '61', '110', '910', '283', '101', '46', '207', '131', '241', '282', '299', '15', '17', '918', '104', '32', '21', '62', '294', '909', '139', '229', '945', '40', '77', '259', '35', '232', '274', '961', '267', '936', '140', '69', '92', '235', '96', '279', '944', '95', '964', '914', '296', '954', '115', '202', '901', '238', '903', '10', '154', '927', '64', '266', '91', '65', '145', '948', '74', '966', '289', '285', '209', '6', '905', '915', '83', '933', '128', '205', '902', '158', '244', '135', '240', '916', '917', '247', '926', '102', '243', '38', '68', '120', '152', '227', '143', '201', '246', '919', '920', '951', '117', '137', '144', '912', '33', '200', '2', '150', '16', '302', '937', '71', '292', '949', '946', '106', '923', '242', '245', '147', '293', '921', '206', '43', '280', '286', '5', '78', '281', '911', '90', '132', '231', '109', '214', '297', '159', '155', '127', '230', '284', '935', '70', '249', '262', '9', '956', '148', '50', '14', '287', '908', '959', '19', '60', '942', '965', '20', '81'}
# Traceback (most recent call last):
#   File "/home/ires/Multilingual_Text_to_Speech/train.py", line 248, in <module>
#     hp.mel_normalize_mean, hp.mel_normalize_variance = dataset.train.get_normalization_constants(True)
#   File "/home/ires/Multilingual_Text_to_Speech/dataset/dataset.py", line 178, in get_normalization_constants
#     spectrogram = self.load_spectrogram(item['audio'], path, False, is_mel)
#   File "/home/ires/Multilingual_Text_to_Speech/dataset/dataset.py", line 155, in load_spectrogram
#     spectrogram = np.load(full_spec_path)
#   File "/home/ires/miniconda3/envs/sar/lib/python3.6/site-packages/numpy/lib/npyio.py", line 416, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ires/Multilingual_Text_to_Speech/data/wav_data/spectrograms/000000.npy'

# %%
# !ls
# Out:
# checkpoints    dataset		_img	    notebooks	      synthesize.py
# CODE.md        dataset_prepare	LICENSE.md  params	      train.py
# data	       evaluation	logs	    README.md	      utils
# data_file.txt  gta.py		modules     requirements.txt
